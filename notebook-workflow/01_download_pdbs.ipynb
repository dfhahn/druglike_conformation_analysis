# %% [markdown]
# # Get the PDB files of the "Drug and Drug Target Mapping" table from the database
# All PDB files in the table (data Nov. 20, 2020) are part of the distribution, so no need to run this notebook.

# %%
import os
import numpy as np
import pandas as pd
from rdkit import Chem
from tqdm.notebook import tqdm
import urllib

# %% [markdown]
# ## Download "Drug and Drug Target Mapping" table from the PDB
# https://www.rcsb.org/pdb/ligand/drugMapping.do

# %%
! wget https://www.rcsb.org/pdb/ligand/drugMapping.do?format=csv&is_target_only=false

# %% [markdown]
# Read in the table with `pandas`

# %%
table = pd.read_csv('drugTable.csv')
print(table.shape)
table.head()
# Out:
# (1215, 13)
#                         Generic Name Brand Name DrugBank ID ATC Codes  \
# 0  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
# 1  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
# 2  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
# 3                  4-Androstenedione        NaN     DB01536       NaN
# 4                  4-Androstenedione        NaN     DB01536       NaN
#
#   Ligand ID                                        Target Name UniProt ID  \
# 0       B41               Synaptic vesicular amine transporter     Q05940
# 1       B41         Sodium-dependent noradrenaline transporter     P23975
# 2       B41             Sodium-dependent serotonin transporter     P31645
# 3       ASD  3 beta-hydroxysteroid dehydrogenase/Delta 5-->...     P14060
# 4       ASD                  Estradiol 17-beta-dehydrogenase 1     P14061
#
#   PDB ID 1 Seq. Identity 1 PDB ID 2 Seq. Identity 2 PDB ID 3 Seq. Identity 3
# 0      NaN             NaN      NaN             NaN      NaN             NaN
# 1      NaN             NaN      NaN             NaN      NaN             NaN
# 2      NaN             NaN      NaN             NaN      NaN             NaN
# 3      NaN             NaN      NaN             NaN      NaN             NaN
# 4     1QYX             89%      NaN             NaN      NaN             NaN

# %% [markdown]
# There are up to 3 PDB codes per row. We want to have one per row, therefore we make copies of the respective rows and create one columns with the PDBs

# %%
newtable = []
for i, row in table.iterrows():
    for j in range(1,4):
        nrow = row.copy()
        nrow['PDB ID'] = row[f'PDB ID {j}']
        nrow['Seq. Identity'] = row[f'Seq. Identity {j}']
        nrow = nrow.drop(labels=[f'PDB ID {k}' for k in range(1,4)]+[f'Seq. Identity {k}' for k in range(1,4)])
        newtable.append(nrow)
newtable = pd.concat(newtable, axis=1).T
newtable.head()
# Out:
#                         Generic Name Brand Name DrugBank ID ATC Codes  \
# 0  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
# 0  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
# 0  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
# 1  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
# 1  3,4-Methylenedioxymethamphetamine        NaN     DB01454       NaN
#
#   Ligand ID                                 Target Name UniProt ID PDB ID  \
# 0       B41        Synaptic vesicular amine transporter     Q05940    NaN
# 0       B41        Synaptic vesicular amine transporter     Q05940    NaN
# 0       B41        Synaptic vesicular amine transporter     Q05940    NaN
# 1       B41  Sodium-dependent noradrenaline transporter     P23975    NaN
# 1       B41  Sodium-dependent noradrenaline transporter     P23975    NaN
#
#   Seq. Identity
# 0           NaN
# 0           NaN
# 0           NaN
# 1           NaN
# 1           NaN

# %% [markdown]
# Filter out all rows with PDB codes being NaN.

# %%
newtable = newtable.loc[newtable['PDB ID'].notna()]
print(newtable.shape)
newtable.head()
# Out:
# (937, 9)
#         Generic Name                          Brand Name DrugBank ID  \
# 4  4-Androstenedione                                 NaN     DB01536
# 6        Abiraterone                              Zytiga     DB05812
# 6        Abiraterone                              Zytiga     DB05812
# 6        Abiraterone                              Zytiga     DB05812
# 7           Acarbose  Acarbose#Glucobay#Precose#Prandase     DB00284
#
#          ATC Codes Ligand ID                               Target Name  \
# 4              NaN       ASD         Estradiol 17-beta-dehydrogenase 1
# 6          L02BX03       AER  Steroid 17-alpha-hydroxylase/17,20 lyase
# 6          L02BX03       AER  Steroid 17-alpha-hydroxylase/17,20 lyase
# 6          L02BX03       AER  Steroid 17-alpha-hydroxylase/17,20 lyase
# 7  A10BF01#A10BD17   ACR,QPS          Maltase-glucoamylase, intestinal
#
#   UniProt ID PDB ID Seq. Identity
# 4     P14061   1QYX           89%
# 6     P05093   3RUK           97%
# 6     P05093   4NKV           97%
# 6     P05093   4R1Z           50%
# 7     O43451   2QMJ           99%

# %% [markdown]
# Remove duplicate pdb codes and reindex with PDB ID

# %%
newtable = newtable.loc[np.invert(newtable.duplicated(subset=['PDB ID'], keep='first'))]
newtable.index = newtable["PDB ID"]
print(newtable.shape)
newtable.head()
# Out:
# (602, 9)
#              Generic Name                          Brand Name DrugBank ID  \
# PDB ID
# 1QYX    4-Androstenedione                                 NaN     DB01536
# 3RUK          Abiraterone                              Zytiga     DB05812
# 4NKV          Abiraterone                              Zytiga     DB05812
# 4R1Z          Abiraterone                              Zytiga     DB05812
# 2QMJ             Acarbose  Acarbose#Glucobay#Precose#Prandase     DB00284
#
#               ATC Codes Ligand ID                               Target Name  \
# PDB ID
# 1QYX                NaN       ASD         Estradiol 17-beta-dehydrogenase 1
# 3RUK            L02BX03       AER  Steroid 17-alpha-hydroxylase/17,20 lyase
# 4NKV            L02BX03       AER  Steroid 17-alpha-hydroxylase/17,20 lyase
# 4R1Z            L02BX03       AER  Steroid 17-alpha-hydroxylase/17,20 lyase
# 2QMJ    A10BF01#A10BD17   ACR,QPS          Maltase-glucoamylase, intestinal
#
#        UniProt ID PDB ID Seq. Identity
# PDB ID
# 1QYX       P14061   1QYX           89%
# 3RUK       P05093   3RUK           97%
# 4NKV       P05093   4NKV           97%
# 4R1Z       P05093   4R1Z           50%
# 2QMJ       O43451   2QMJ           99%

# %% [markdown]
# ## Download PDB files. If not available, download CIFs and convert to PDB

# %%
! mkdir -p pdb

# %% [markdown]
# The following cell calls maxit (https://sw-tools.rcsb.org/apps/MAXIT/index.html) to convert CIF to PDB files. All pdb files are part of the distribution, so if you do not have maxit, you will not need to install it.

# %%
for i, row in tqdm(newtable.iterrows()):
    if not os.path.exists(f'pdb/{row[f"PDB ID"]}.pdb'):
        try:
            address = f'https://files.rcsb.org/download/{row[f"PDB ID"].lower()}.pdb'
            urllib.request.urlretrieve(address, f'pdb/{row[f"PDB ID"]}.pdb')
        except urllib.error.HTTPError as e:
            print(f'PDB Error while retrieving {row[f"PDB ID"]}: {e}')
            # if pdb is not available, try to download cif file
            if not os.path.exists(f'pdb/{row[f"PDB ID"]}.cif'):
                try:
                    address = f'https://files.rcsb.org/download/{row[f"PDB ID"].lower()}.cif'
                    urllib.request.urlretrieve(address, f'pdb/{row[f"PDB ID"]}.cif')
                except urllib.error.HTTPError as e:
                    print(f'PDB Error while retrieving mmCIF file of  {row[f"PDB ID"]}: {e}')
                    
            # Convert CIF files to pdb; https://sw-tools.rcsb.org/apps/MAXIT/index.html
            inp = f'pdb/{row["PDB ID"]}.cif'
            out = f'pdb/{row["PDB ID"]}.pdb'
            ! maxit -input $inp -output $out -o 2 -log logfile
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…

# %% [markdown]
# ## Save table to CSV

# %%
newtable.to_csv('drug_table_cleaned.csv')
